# %% [markdown]
# # Haberman's Survival Data Analysis

# %% [markdown]
# ### Description:
#
# - The dataset contains cases from a study that was conducted between 1958 and 1970 at the University of Chicago's Billings Hospital on the survival of patients who had undergone surgery for breast cancer.

# %% [markdown]
# ### Relevant Information:
#
# - The dataset contains cases from a study that was conducted between 1958 and 1970 at the University of Chicago's Billings Hospital on the survival of patients who had undergone surgery for breast cancer.
#
# - Number of Instances: 306
#
# - Number of Attributes: 4 (including the class attribute)
#
# - Attribute Information:
#
#     - Age of patient at time of operation (numerical)
#     - Patient's year of operation (year - 1900, numerical)
#     - Number of positive axillary nodes detected (numerical)
#     - Survival status (class attribute) 1 = the patient survived 5 years or longer 2 = the patient died within 5 year
#
# - Missing Attribute Values: None

# %%
## Importing libraries :
import os 
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## Importing the file :

hbman = pd.read_csv("../input/haberman-csv/haberman.csv")
print (hbman.shape)
# Out:
# (306, 4)

# %% [markdown]
# ###    Data Analysis:

# %%
print(hbman.columns)
# Out:
# Index(['year', 'age', 'nodes', 'status'], dtype='object')

# %%
hbman
# Out:
#      year  age  nodes  status
# 0      30   64      1       1
# 1      30   62      3       1
# 2      30   65      0       1
# 3      31   59      2       1
# 4      31   65      4       1
# ..    ...  ...    ...     ...
# 301    75   62      1       1
# 302    76   67      0       1
# 303    77   65      3       1
# 304    78   65      1       2
# 305    83   58      2       2
#
# [306 rows x 4 columns]

# %%
print ("YEAR DISCRIPTION")
hbman["year"].value_counts()
# Out:
# YEAR DISCRIPTION
# 52    14
# 54    13
# 50    12
# 47    11
# 53    11
# 43    11
# 57    11
# 49    10
# 65    10
# 55    10
# 38    10
# 41    10
# 42     9
# 45     9
# 61     9
# 59     8
# 63     8
# 56     7
# 58     7
# 62     7
# 48     7
# 46     7
# 44     7
# 70     7
# 34     7
# 51     6
# 67     6
# 39     6
# 37     6
# 60     6
# 66     5
# 64     5
# 69     4
# 72     4
# 30     3
# 40     3
# 31     2
# 68     2
# 36     2
# 35     2
# 33     2
# 73     2
# 74     2
# 71     1
# 75     1
# 76     1
# 77     1
# 78     1
# 83     1
# Name: year, dtype: int64

# %%
print ("AGE DISCRIPTION")
hbman["age"].value_counts()
# Out:
# AGE DISCRIPTION
# 58    36
# 64    31
# 63    30
# 65    28
# 60    28
# 66    28
# 59    27
# 61    26
# 67    25
# 62    23
# 68    13
# 69    11
# Name: age, dtype: int64

# %%
print ("NODE DISCRIPTION")
hbman["nodes"].value_counts()
# Out:
# NODE DISCRIPTION
# 0     136
# 1      41
# 3      20
# 2      20
# 4      13
# 7       7
# 6       7
# 8       7
# 9       6
# 5       6
# 13      5
# 14      4
# 11      4
# 22      3
# 19      3
# 23      3
# 15      3
# 10      3
# 20      2
# 12      2
# 21      1
# 52      1
# 30      1
# 16      1
# 24      1
# 46      1
# 18      1
# 35      1
# 17      1
# 25      1
# 28      1
# Name: nodes, dtype: int64

# %%
print ("STATUS DESCRIPTION")
hbman["status"].value_counts()
# Out:
# STATUS DESCRIPTION
# 1    225
# 2     81
# Name: status, dtype: int64

# %%
year = hbman["year"]
age = hbman["age"]
nodes = hbman["nodes"]
status = hbman["status"]

# %% [markdown]
# ## Uni-variate Analysis:

# %% [markdown]
# ### Scatter-plot :

# %%
plt.title("Haberman Analysis")
plt.scatter(year, age)
plt.xlabel("year")
plt.ylabel("age")
plt.show()
plt.scatter(year,nodes)
plt.xlabel("year")
plt.ylabel("nodes")
plt.show()
plt.scatter(year, status)
plt.xlabel("year")
plt.ylabel("status")
plt.show()
plt.scatter(age, nodes)
plt.xlabel("age")
plt.ylabel("nodes")
plt.show()
plt.scatter(age, status)
plt.xlabel("age")
plt.ylabel("status")
plt.show()
plt.scatter(nodes, status)
plt.xlabel("nodes")
plt.ylabel("status")
plt.show()

# %% [markdown]
# #### 1.2- Observations :

# %% [markdown]
# - The Effected Age group is in between 58 yrs to 69 yrs .
# - During the years 1970 ot 1980 the cases are less detected .
# - The probability of nodes significantly increases at the age of 58 .

# %% [markdown]
# ## Bi-variate Analysis:

# %% [markdown]
# ### 2-D Scatter Plot:

# %%
sns.set_style("whitegrid");
sns.FacetGrid(hbman, hue="status", size=5) \
    .map(plt.scatter, "year", "age") \
    .add_legend();
plt.show();
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style("whitegrid");
sns.FacetGrid(hbman, hue="status", size=5) \
   .map(plt.scatter, "year", "nodes") \
   .add_legend();
plt.show();
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style("whitegrid");
sns.FacetGrid(hbman, hue="status", size=5) \
   .map(plt.scatter, "age", "nodes") \
   .add_legend();
plt.show();
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #### Observations :
#
# - It is very difficult to obtain a decision surface to differentiate the concerned classes .

# %% [markdown]
# ### 3-D Scatter plot :

# %%
plt.close();
sns.set_style("whitegrid");
sns.pairplot(hbman, hue="status", size=4);
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #### Observation :
#
# - As the data-points are distributed in all regions so it is very difficult to find a decision surface .

# %% [markdown]
# ### Histogram, CDF, PDF :

# %%
survived = hbman.loc[hbman['status'] == 1 ];
ntsurvived = hbman.loc[hbman['status'] == 2 ];

plt.plot(survived["year"] , np.zeros_like(survived), 'o')
plt.plot(ntsurvived["year"], np.zeros_like(ntsurvived), 'o')
plt.show()
plt.plot(survived["age"] , np.zeros_like(survived), 'o')
plt.plot(ntsurvived["age"], np.zeros_like(ntsurvived), 'o')
plt.show()
plt.plot(survived["nodes"] , np.zeros_like(survived), 'o')
plt.plot(ntsurvived["nodes"], np.zeros_like(ntsurvived), 'o')
plt.show()

# %%
sns.FacetGrid(hbman, hue="status", size=5) \
   .map(sns.distplot, "year") \
   .add_legend();
plt.show();

sns.FacetGrid(hbman, hue="status", size=5) \
   .map(sns.distplot, "age") \
   .add_legend();
plt.show();

sns.FacetGrid(hbman, hue="status", size=5) \
   .map(sns.distplot, "nodes") \
   .add_legend();
plt.show();
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
#   ### CDF AND PDF:

# %%
# probability density function and cummalative distribution function 

counts, bin_edges = np.histogram(survived['age'], bins=10, density = True)
print (counts) ;
print (bin_edges) ;
pdf = counts/(sum(counts))
print ("Histogram of Survived - Age")
print(pdf);
print(bin_edges);
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf);
plt.plot(bin_edges[1:], cdf)

counts, bin_edges = np.histogram(survived['year'], bins=10, density = True)
print (counts) ;
print (bin_edges) ;
pdf = counts/(sum(counts))
print ("Histogram of Survived - Year")
print(pdf);
print(bin_edges);
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf);
plt.plot(bin_edges[1:], cdf)

counts, bin_edges = np.histogram(survived['nodes'], bins=10, density = True)
print (counts) ;
print (bin_edges) ;
pdf = counts/(sum(counts))
print ("Histogram of Survived - Nodes")
print(pdf);
print(bin_edges);
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf);
plt.plot(bin_edges[1:], cdf)

plt.show() 

counts, bin_edges = np.histogram(ntsurvived['age'], bins=10, density = True)
print (counts) ;
print (bin_edges) ;
pdf = counts/(sum(counts))
print ("Histogram of Not survived - age")
print(pdf);
print(bin_edges);
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf);
plt.plot(bin_edges[1:], cdf)

counts, bin_edges = np.histogram(ntsurvived['year'], bins=10, density = True)
print (counts) ;
print (bin_edges) ;
pdf = counts/(sum(counts))
print ("Histogram of Not survived - Year")
print(pdf);
print(bin_edges);
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf);
plt.plot(bin_edges[1:], cdf)

counts, bin_edges = np.histogram(survived['nodes'], bins=10, density = True)
print (counts) ;
print (bin_edges) ;
pdf = counts/(sum(counts))
print ("Histogram of Not survived - Nodes")
print(pdf);
print(bin_edges);
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf);
plt.plot(bin_edges[1:], cdf)
plt.show()
# Out:
# [0.16969697 0.0969697  0.09292929 0.06464646 0.08888889 0.09292929
#  0.06060606 0.08888889 0.08484848 0.06868687]
# [58.  59.1 60.2 61.3 62.4 63.5 64.6 65.7 66.8 67.9 69. ]
# Histogram of Survived - Age
# [0.18666667 0.10666667 0.10222222 0.07111111 0.09777778 0.10222222
#  0.06666667 0.09777778 0.09333333 0.07555556]
# [58.  59.1 60.2 61.3 62.4 63.5 64.6 65.7 66.8 67.9 69. ]
# [0.01134752 0.02269504 0.02647754 0.01985816 0.03498818 0.03498818
#  0.01985816 0.02364066 0.01323877 0.00567376]
# [30.  34.7 39.4 44.1 48.8 53.5 58.2 62.9 67.6 72.3 77. ]
# Histogram of Survived - Year
# [0.05333333 0.10666667 0.12444444 0.09333333 0.16444444 0.16444444
#  0.09333333 0.11111111 0.06222222 0.02666667]
# [30.  34.7 39.4 44.1 48.8 53.5 58.2 62.9 67.6 72.3 77. ]
# [0.18164251 0.0173913  0.00483092 0.0057971  0.00386473 0.00096618
#  0.00193237 0.         0.         0.00096618]
# [ 0.   4.6  9.2 13.8 18.4 23.  27.6 32.2 36.8 41.4 46. ]
# Histogram of Survived - Nodes
# ...

# %% [markdown]
# ### Mean, Variance and Std-dev

# %%
print("Means:")
print ("Mean age Survived and Not-survived")
print(np.mean(survived["age"]))
print(np.mean(ntsurvived["age"]))
print ("Mean Year Survived and Not-Survived")
print(np.mean(survived["year"]))
print(np.mean(ntsurvived["year"]))
print ("Mean node Survived and Not-Survived")
print(np.mean(survived["nodes"]))
print(np.mean(ntsurvived["nodes"]))

print("\nStd-dev:");
print ("Std-Deviation age Survived and Not-survived")
print(np.std(survived["age"]))
print(np.std(ntsurvived["age"]))
print ("Std-Deviation year Survived and Not-survived")
print(np.std(survived["year"]))
print(np.std(ntsurvived["year"]))
print ("Std-Deviation nodes Survived and Not-survived")
print(np.std(survived["nodes"]))
print(np.std(ntsurvived["nodes"]))
# Out:
# Means:
# Mean age Survived and Not-survived
# 62.86222222222222
# 62.82716049382716
# Mean Year Survived and Not-Survived
# 52.01777777777778
# 53.67901234567901
# Mean node Survived and Not-Survived
# 2.7911111111111113
# 7.45679012345679
#
# Std-dev:
# Std-Deviation age Survived and Not-survived
# 3.2157452144021956
# 3.3214236255207883
# Std-Deviation year Survived and Not-survived
# 10.98765547510051
# 10.10418219303131
# Std-Deviation nodes Survived and Not-survived
# 5.857258449412131
# 9.128776076761632

# %% [markdown]
# ### Median, Percentile, Quantile, IQR, MAD:

# %%
print("\nMedians:")
print ("median of survived and not survived - Age" )
print(np.median(survived["age"]))
print(np.median(ntsurvived["age"]))
print ("median of survived and not survived - Year" )
print(np.median(survived["year"]))
print(np.median(ntsurvived["year"]))
print ("median of survived and not survived - Nodes" )
print(np.median(survived["nodes"]))
print(np.median(ntsurvived["nodes"]))


print("\nQuantiles:")
print ("Percentile of survived and not survived - Age" )
print(np.percentile(survived["age"],np.arange(0, 100, 25)))
print(np.percentile(ntsurvived["age"],np.arange(0, 100, 25)))
print ("Percentile of survived and not survived - Year" )
print(np.percentile(survived["year"],np.arange(0, 100, 25)))
print(np.percentile(ntsurvived["year"],np.arange(0, 100, 25)))
print ("Percentile of survived and not survived - Nodes" )
print(np.percentile(survived["nodes"],np.arange(0, 100, 25)))
print(np.percentile(ntsurvived["nodes"],np.arange(0, 100, 25)))

print("\n90th Percentiles:")
print ("90th Percentile of survived and not survived - Age" )
print(np.percentile(survived["age"],90))
print(np.percentile(ntsurvived["age"],90))
print ("90th Percentile of survived and not survived - Year" )
print(np.percentile(survived["year"],90))
print(np.percentile(ntsurvived["year"],90))
print ("90th Percentile of survived and not survived - Nodes" )
print(np.percentile(survived["nodes"],90))
print(np.percentile(ntsurvived["nodes"],90))

from statsmodels import robust
print ("\nMedian Absolute Deviation")
print ("Mean std dev. of survived and not survived - Age" )
print(robust.mad(survived["age"]))
print(robust.mad(ntsurvived["age"]))
print ("Mean std dev. of survived and not survived - Year" )
print(robust.mad(survived["year"]))
print(robust.mad(ntsurvived["year"]))                    
print ("Mean std dev. of survived and not survived - Nodes" )
print(robust.mad(survived["nodes"]))
print(robust.mad(ntsurvived["nodes"]))
# Out:
# Medians:
# median of survived and not survived - Age
# 63.0
# 63.0
# median of survived and not survived - Year
# 52.0
# 53.0
# median of survived and not survived - Nodes
# 0.0
# 4.0
#
# Quantiles:
# Percentile of survived and not survived - Age
# [58. 60. 63. 66.]
# [58. 59. 63. 65.]
# Percentile of survived and not survived - Year
# [30. 43. 52. 60.]
# [34. 46. 53. 61.]
# Percentile of survived and not survived - Nodes
# [0. 0. 0. 3.]
# [ 0.  1.  4. 11.]
#
# 90th Percentiles:
# 90th Percentile of survived and not survived - Age
# 67.0
# 67.0
# 90th Percentile of survived and not survived - Year
# 67.0
# 67.0
# 90th Percentile of survived and not survived - Nodes
# 8.0
# 20.0
#
# Median Absolute Deviation
# Mean std dev. of survived and not survived - Age
# 4.447806655516806
# 4.447806655516806
# Mean std dev. of survived and not survived - Year
# 13.343419966550417
# 11.860817748044816
# Mean std dev. of survived and not survived - Nodes
# 0.0
# 5.930408874022408

# %% [markdown]
# ### BOX PLOT :

# %%
sns.boxplot(x="status", y="age", data=hbman)
plt.show()
sns.boxplot(x="status", y="year", data=hbman)
plt.show()
sns.boxplot(x="status", y="nodes", data=hbman)
plt.show()

# %% [markdown]
# ### Violin plot:

# %%
sns.violinplot(x="status", y="age", data=hbman, size=8)
plt.show()
sns.violinplot(x="status", y="year", data=hbman, size=8)
plt.show()
sns.violinplot(x="status", y="nodes", data=hbman, size=8)
plt.show()

# %% [markdown]
# ## Multivariate Analysis:

# %% [markdown]
# ### 3D Scatter plot :

# %%
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
import random

fig = pyplot.figure()
ax = Axes3D(fig)

ax.scatter(age, year, nodes, c='r', marker='o')
ax.set_xlabel('age')
ax.set_ylabel('year')
ax.set_zlabel('nodes')
pyplot.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.

# %%
fig = pyplot.figure()
ax = Axes3D(fig)
ax.scatter(status, age, year, c='b', marker='o')
ax.set_xlabel('status')
ax.set_ylabel('age')
ax.set_zlabel('year')
pyplot.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.

# %%
fig = pyplot.figure()
ax = Axes3D(fig)
ax.scatter(year,nodes,status, c='b', marker='o')
ax.set_xlabel('year')
ax.set_ylabel('nodes')
ax.set_zlabel('status')
pyplot.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.

# %% [markdown]
# ### Contour Plot:

# %%
sns.jointplot(x="year", y="status", data=hbman, kind="kde");
plt.show();

# %% [markdown]
# ## Observation:

# %% [markdown]
# - The Effected Age group is in between 58 yrs to 69 yrs .
# - During the years 1970 ot 1980 the cases are less detected .
# - The probability of nodes significantly increases at the age of 58 .
# - Number of nodes is an important feature .
